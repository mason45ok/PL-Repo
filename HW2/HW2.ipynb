# %% [markdown]
# 問題一:世界各區域的預期壽命變化，理論上，在經歷戰爭後，各大洲的預期壽命會保持上升，同時我希望比較各大洲是誰的預期壽命小於世界的水平，圖中還額外顯示了2019年，全世界的預期壽命都下挫，我認為是和新冠疫情有關。

# %%
import pandas as pd
import plotly.express as px

# 读取数据
df = pd.read_csv('LF.csv', encoding='utf-8')

# 使用Plotly Express绘制折线图
fig = px.line(df.melt(id_vars='Country Name', var_name='Year', value_name='Life Expectancy'), 
              x='Year', y='Life Expectancy', color='Country Name',
              title='Life Expectancy Over Time by Country')

# 显示图表
fig.show()

# %% [markdown]
# 問題二:由問題一可知，美國和東南非洲的預期壽命差距非常大，同時我們知道GDP可以被當作衡量經濟狀況的因素，那麼預期壽命會和GDP有相關才對，國家的國力好會使人民的經濟狀況好的同時，提升醫療水平使人的預期壽明提高，下圖明確表示預期壽命和國家GDP有關，美國的GDP近乎全程都是東南非洲的十倍以上，所以預期壽命的確可以通過GDP做預測，圖中也顯示了2019和2020 GDP都發生了下挫，符合上圖的新冠猜想。

# %%
import pandas as pd
import plotly.express as px

# 读取数据
df = pd.read_csv('GDP.csv', encoding='utf-8')

# 使用Plotly Express绘制折线图
fig = px.line(df.melt(id_vars='Country Name', var_name='Year', value_name='GDP'), 
              x='Year', y='GDP', color='Country Name',
              title='GDP Over Time by Country')

# 显示图表
fig.show()
